# %% [markdown]
# <a href="https://colab.research.google.com/github/CardosoDM745/Atividade_python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Atividade 01 - Introdução ao Python
print ('Olá, mundo')
print("curso técnico de informática")
# Out:
# Olá, mundo
# curso técnico de informática

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print("Resultado:", soma)
# Out:
# Resultado: 30

# %%
disciplina = input("Digite o nome da disciplina:")
conteudo = input("Digite o conteúdo estudado;")
atividade = int(input("Digite o número da atividade:"))
print("\n--Informações da atividade---")
print("Disciplina", disciplina)
print("Conteúdo;", conteudo)
print("atividade", atividade)
# Out:
# Digite o nome da disciplina:Progamação orientada a objetos
# Digite o conteúdo estudado;Java
# Digite o número da atividade:9
#
# --Informações da atividade---
# Disciplina Progamação orientada a objetos
# Conteúdo; Java
# atividade 9
